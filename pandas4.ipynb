# %% [markdown]
# # selecting a subset of the dataframe

# %%
import pandas as pd

# %%
popList = pd.read_excel("world_population_excel_workbook.xlsx")
popList
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El Aai̼n    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
pop_2020 = popList['2020 Population']
pop_2020
# Out:
# 0      38972230
# 1       2866849
# 2      43451666
# 3         46189
# 4         77700
#          ...
# 229       11655
# 230      556048
# 231    32284046
# 232    18927715
# 233    15669666
# Name: 2020 Population, Length: 234, dtype: int64

# %%
pop_2020.shape
# Out:
# (234,)

# %%
country_2020pop = popList[["Country","2020 Population"]]
country_2020pop
# Out:
#                Country  2020 Population
# 0          Afghanistan         38972230
# 1              Albania          2866849
# 2              Algeria         43451666
# 3       American Samoa            46189
# 4              Andorra            77700
# ..                 ...              ...
# 229  Wallis and Futuna            11655
# 230     Western Sahara           556048
# 231              Yemen         32284046
# 232             Zambia         18927715
# 233           Zimbabwe         15669666
#
# [234 rows x 2 columns]

# %%
country_2020pop.shape
# Out:
# (234, 2)

# %%
#filter out population > 40000000
above_40million = popList[popList["2020 Population"] > 200000000]
above_40million
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27         215313498        213196304        205188205        196353492
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 93         275501339        271857970        259091970        244016173
# 149        218541212        208327405        183995785        160952853
# ...

# %%
popList["2020 Population"] > 400000000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: 2020 Population, Length: 234, dtype: bool

# %%
res = popList["2020 Population"].isin(["South America"])
res
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: 2020 Population, Length: 234, dtype: bool

# %%
res1 = popList.loc[popList["Continent"] == "South America", "Country"]
res1
# Out:
# 8             Argentina
# 24              Bolivia
# 27               Brazil
# 40                Chile
# 42             Colombia
# 56              Ecuador
# 64     Falkland Islands
# 69        French Guiana
# 86               Guyana
# 161            Paraguay
# 162                Peru
# 199            Suriname
# 223             Uruguay
# 227           Venezuela
# Name: Country, dtype: object

# %%
#rows 10 to 30 and columns 1 to 5
res2 = popList.iloc[10:30, 1:5]
res2
# Out:
#    CCA3                 Country              Capital      Continent
# 10  ABW                   Aruba           Oranjestad  North America
# 11  AUS               Australia             Canberra        Oceania
# 12  AUT                 Austria               Vienna         Europe
# 13  AZE              Azerbaijan                 Baku           Asia
# 14  BHS                 Bahamas               Nassau  North America
# 15  BHR                 Bahrain               Manama           Asia
# 16  BGD              Bangladesh                Dhaka           Asia
# 17  BRB                Barbados           Bridgetown  North America
# 18  BLR                 Belarus                Minsk         Europe
# 19  BEL                 Belgium             Brussels         Europe
# 20  BLZ                  Belize             Belmopan  North America
# 21  BEN                   Benin           Porto-Novo         Africa
# 22  BMU                 Bermuda             Hamilton  North America
# ...
