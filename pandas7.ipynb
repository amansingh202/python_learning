# %% [markdown]
# # Calculate summary statistics

# %%
#pandas 7th code with summary statistics
import pandas as pd

# %%
df = pd.read_csv("population_of_world.csv")
df.head(12)
# Out:
#     Unnamed: 0  Rank CCA3              Country           Capital  \
# 0            0    36  AFG          Afghanistan             Kabul
# 1            1   138  ALB              Albania            Tirana
# 2            2    34  DZA              Algeria           Algiers
# 3            3   213  ASM       American Samoa         Pago Pago
# 4            4   203  AND              Andorra  Andorra la Vella
# 5            5    42  AGO               Angola            Luanda
# 6            6   224  AIA             Anguilla        The Valley
# 7            7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8            8    33  ARG            Argentina      Buenos Aires
# 9            9   140  ARM              Armenia           Yerevan
# 10          10   198  ABW                Aruba        Oranjestad
# 11          11    55  AUS            Australia          Canberra
#
#         Continent  2022 Population  2020 Population  2015 Population  \
# ...

# %%
#mean of the data
df["2022 Population"].mean()
# Out:
# 34074414.70940171

# %%
#median of the data
df[["2022 Population", "2020 Population"]].median()
# Out:
# 2022 Population    5559944.5
# 2020 Population    5493074.5
# dtype: float64
